# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 =pd.read_csv("/content/college_1.csv") 
df2 =pd.read_csv("/content/college_2.csv")

# %%
df1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
df2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df =pd.concat([df1,df2])
df
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %%
df.describe()
# Out:
#            python       mysql  Previous Geekions  CodeKata Score       Rising  \
# count  119.000000  119.000000         119.000000      119.000000   119.000000
# mean    54.352941   23.500000        3842.352941     4051.764706   209.411765
# std     44.272526   33.276671        4406.339992     4551.951881   553.445746
# min     -1.000000   -1.000000           0.000000        0.000000     0.000000
# 25%      0.000000    0.000000         740.000000      740.000000     0.000000
# 50%     82.000000    4.000000        2410.000000     2410.000000     0.000000
# 75%    100.000000   33.000000        5340.000000     5975.000000     0.000000
# max    100.000000  100.000000       24500.000000    24500.000000  3140.000000
#
#         python_en  computational_thinking
# count   35.000000               35.000000
# mean    29.657143                2.200000
# std     30.582524                7.015948
# min     -1.000000               -1.000000
# 25%      0.000000                0.000000
# ...

# %%
df.head(30)
# Out:
#                     Name  python   mysql  Previous Geekions  CodeKata Score  \
# 0              A.Dharani    82.0   20.00              24500           24500
# 1            V.JEEVITHA     82.0   20.00              21740           21740
# 2            HEMAVATHI.R   100.0  100.00              19680           19680
# 3            Mugunthan S   100.0   47.00              10610           10610
# 4            Sathammai.S   100.0    8.00               8980            8980
# 5           NIVEESHWAR S   100.0    0.00               8200            8200
# 6          KALAIARASAN K    85.0   47.00               7750            7880
# 7   MOHAMED ZUBAIR AHMED    82.0    4.00               7020            7020
# 8             J.SUGANTHI    27.0   50.00               5860            5860
# 9           thamizhpaana    29.0    0.00               5500            5500
# 10       Iyappan Samiraj    50.0   24.00               5400            5400
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
df_exceeded = df[df['CodeKata Score']>15000]
df_exceeded.to_csv('Exceeded expectations.csv')

# %%
df_exceeded
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 0  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 0  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 0                     9.0

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
df_reached = df[(df['CodeKata Score']>10000) &  (df['CodeKata Score']<15000)]
df_reached.to_csv('Reached_expectations.csv')

# %%
df_improvement = df[(df['CodeKata Score']>7000) &  (df['CodeKata Score']<10000)]
df_improvement.to_csv ("Needs_Improvement.csv")

# %%
df_unsatisfactory = df[df['CodeKata Score']<7000]
df_unsatisfactory.to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### No of students participated

# %%
df_students = df["Name"].count()
df_students
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
df["python"].mean()
# Out:
# 54.35294117647059

# %%
df["mysql"].mean()
# Out:
# 23.5

# %%
df["python_en"].mean()
# Out:
# 29.65714285714286

# %%
df["computational_thinking"].mean()
# Out:
# 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df.nlargest(3,'Rising')
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 2         Computer Science and Engineering    2000       55.0
# 18        Computer Science and Engineering    2000       -1.0
#
#     computational_thinking
# 8                      0.0
# 2                      6.0
# 18                     0.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df.nlargest(3,'Previous Geekions')
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df['Department'].unique()
# Out:
# array(['Computer Science and Engineering',
#        'Electronics and Communication Engineering',
#        'Electronics and Electrical Engineering'], dtype=object)

# %%
department = df.groupby('Department').sum()
department
# Out:
#                                            python    mysql  Previous Geekions  \
# Department
# Computer Science and Engineering           3844.0  1397.25             301935
# Electronics and Communication Engineering  1532.5  1057.25             107325
# Electronics and Electrical Engineering     1091.5   342.00              47980
#
#                                            CodeKata Score  Rising  python_en  \
# Department
# Computer Science and Engineering                   320025   18090      487.0
# Electronics and Communication Engineering          108335    1010      351.0
# Electronics and Electrical Engineering              53800    5820      200.0
#
#                                            computational_thinking
# Department
# Computer Science and Engineering                             23.0
# Electronics and Communication Engineering                    46.0
# Electronics and Electrical Engineering                        8.0

# %%
#creating a pie chart 
departments = ['Computer Science and Engineering', 'Electronics and Communication Engineering','Electronics and Electrical Engineering']
codekata_scores = [320025,107325,47980]
myexplode = [0.0, 0.2, 0.4]
plt.pie(codekata_scores, labels=departments, autopct='%1.1f%%',shadow = True,explode = myexplode)
plt.title('Department wise codekata performence')
plt.show()

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
#find the toppers in each department 
toppers = df.groupby('Department').apply(lambda x: x[x['CodeKata Score'] == x['CodeKata Score'].max()])

#display the data
print(toppers[['Name','Department','CodeKata Score']])
# Out:
#                                                         Name  \
# Department
# Computer Science and Engineering          0        A.Dharani
# Electronics and Communication Engineering 3  Bodipudi Harini
# Electronics and Electrical Engineering    0    ASHOK KUMAR K
#
#                                                                             Department  \
# Department
# Computer Science and Engineering          0           Computer Science and Engineering
# Electronics and Communication Engineering 3  Electronics and Communication Engineering
# Electronics and Electrical Engineering    0     Electronics and Electrical Engineering
#
#                                              CodeKata Score
# Department
# Computer Science and Engineering          0           24500
# Electronics and Communication Engineering 3           10040
# Electronics and Electrical Engineering    0           19400

# %%
toppers.plot.barh(x='Name',y='CodeKata Score',title='Department Toppers')
